# %%
import tweepy
import keras
from keras.preprocessing.text import Tokenizer

# %%
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAAANXcAEAAAAANHpdI2uNYN8CkcFy3QLfQe52Zm0%3DzTjMP8sxXQLxkhy84d3g8zdmzewnkjAzIXJiwrPIMwqUFlGZ9K')

# Get all first 100(n) tweets
# -is:retweet means I don't want retweets
# lang:en is asking for the tweets to be in english
query = 'all -is:retweet lang:en'
tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)

for tweet in tweets.data:
    print(tweet.text)
#    if len(tweet.context_annotations) > 0:
#        print(tweet.context_annotations)

#tokenization
tokenizer = Tokenizer(num_words=None, filters='I"#$%&()*+,-./:;<=>?@[\J^_(I]N\t\n', lower=True, split=' ')

# Train the tokenizer to the texts
tokenizer.fit_on_texts(tweet.text)

# Convert List of strings into List of Lists of integers
sequences = tokenizer.texts_to_sequences(tweet.text)
print(sequences)
# Out:
# We all hung out in a coffee shop called Poopies up on the strip https://t.co/Ou7pjKOTvD
# #Camden #WestVirginia #Michigan, We're happy to #followback and retweet all #SME's! Small and medium size enterprises are the backbone of the #economy, join me in supporting them! https://t.co/x9XrhJBFEH
# Excited to show you this complete, just know its gonna look 👌
#
# Shadow gap LED lighting strip installation carried out by our lads James &amp; Jake.
# supplied by @yesss manufactured via @all.led
# #striplighting #LEDlighting #electrcial #surrey #electrcialcontractors https://t.co/EacVQdFJ8P
# Don’t tell me you’re in a gang cause ima ask how you came home &amp; y’all freeze up every time🥶😩 ain’t no way y’all were all “blessed in”
# Morning all, ELT signing in for the early shift👋
#
# Have a good day😀 https://t.co/be2cZ8OzpO
# I mean all I got are just jpegs as nft and am worth like next generations ain't got to hustle 💯 😄😄 @NFTPixelWarrior
# ...
